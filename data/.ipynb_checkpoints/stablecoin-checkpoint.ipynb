# %%
import requests
import pandas as pd
from datetime import datetime
import os
import matplotlib.pyplot as plt

# %%
def concatenate_csv_files(folder_path):
    all_dataframes = []

    for file_name in os.listdir(folder_path):
        if file_name.endswith('.csv'):
            file_path = os.path.join(folder_path, file_name)
            df = pd.read_csv(file_path)
            all_dataframes.append(df)
    
    concatenated_df = pd.concat(all_dataframes, ignore_index=True)
    return concatenated_df

# %%
folder = "./BAC Transfers"  # Replace with your folder path
df = concatenate_csv_files(folder)
df
# Out:
#                                        Transaction Hash   Status    Type  \
# 0     0xa498f3f77082b3f954d18f73ae611459f80874ee1efd...  Success  ERC-20
# 1     0xa498f3f77082b3f954d18f73ae611459f80874ee1efd...  Success  ERC-20
# 2     0x90dc91555721fed98f7484db5d7db7e4233db82ba568...  Success  ERC-20
# 3     0x670785809faeb43c2a5a7fcea4c03204dae489fb4898...  Success  ERC-20
# 4     0x07ee0ac83b5e9e37635635af2268def6ac3c67ad923f...  Success  ERC-20
# ...                                                 ...      ...     ...
# 9574  0x7f6c82c289d56203020f569ab1b6caa465aed9a39785...  Success  ERC-20
# 9575  0x00cc3634129e9874f7de197074632bd05d59e468ae97...  Success  ERC-20
# 9576  0x47e23c3f3f2a0858e2450e40eeeae0290ede15a63c4b...  Success  ERC-20
# 9577  0xade4d82ae8b3d38216cb433fc3b16a1ef8402bbdc97a...  Success  ERC-20
# 9578  0xd50106d18fd41393e5cc6c0615149afea36673d35a7f...  Success  ERC-20
#
#                            Method      Block     Date Time (UTC)  \
# 0                       0x415565b0  11651648  2021-01-14 6:37:59
# 1                       0x415565b0  11651648  2021-01-14 6:37:59
# 2                             Exit  11651646  2021-01-14 6:37:31
# 3                     Claim Reward  11651645  2021-01-14 6:37:23
# 4     Swap Exact Tokens For Tokens  11651645  2021-01-14 6:37:23
# ...                            ...       ...                 ...
# 9574                 Add Liquidity  11669826  2021-01-17 1:48:31
# 9575  Swap Exact Tokens For Tokens  11669821  2021-01-17 1:47:06
# 9576     Swap Exact Tokens For ETH  11669763  2021-01-17 1:35:21
# 9577                          Exit  11669757  2021-01-17 1:33:44
# 9578  Swap Exact Tokens For Tokens  11669695  2021-01-17 1:19:55
#
#                                             From  \
# 0     0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
# 1     0x22f9dcf4647084d6c31b2765f6910cd85c178c18
# 2     0x4330E43F5b1e7D3Ea7B0a177Af50C6B2489ca406
# 3     0x4b182469337d46e6603ed7e26ba60c56930a342c
# 4     0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
# ...                                          ...
# 9574  0xF44C4eD93F52a61d4c8e441c5b6c579d58D00a02
# 9575  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
# 9576  0x6f9b1E4e3e5E1E2EB797D53a666B0d9963EA761D
# 9577  0x83dAc1C1A5832d2037Ed21D597141026f52D151F
# 9578  0x33564D15CE3375D2b41bE509e087e453032575f6
#
#                          From_NameTag  \
# 0                 Uniswap V2: BAC-DAI
# 1     0x: Exchange Proxy Flash Wallet
# 2
# 3               Basis Cash: Boardroom
# 4                 Uniswap V2: BAC-DAI
# ...                               ...
# 9574
# 9575              Uniswap V2: BAC-DAI
# 9576
# 9577
# 9578
#
#                                               To  \
# 0     0x22f9dcf4647084d6c31b2765f6910cd85c178c18
# 1     0x23b11ff67c2193b97cb37771d15a537b977d2278
# 2     0xC6a415148171ad5284E15C8c3d344c3E81d60226
# 3     0xcc0f9D680C48BC785B7a7b6155b37AbeAE191290
# 4     0x2ea2A99ceD3e1bd788c2cB62B1bDe14d92392Ba5
# ...                                          ...
# 9574  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
# 9575  0xF44C4eD93F52a61d4c8e441c5b6c579d58D00a02
# 9576  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
# 9577  0x6f9b1E4e3e5E1E2EB797D53a666B0d9963EA761D
# 9578  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd
#
#                             To_NameTag         Amount Value (USD)      Asset  \
# 0      0x: Exchange Proxy Flash Wallet   13,035.43101       $21.73  BAC(BAC)
# 1                        wandernut.eth   13,035.43101       $21.73  BAC(BAC)
# 2                                          25,586.401       $42.65  BAC(BAC)
# 3                                          357.270707      $0.5955  BAC(BAC)
# 4                                       96,133.282525      $160.24  BAC(BAC)
# ...                                ...            ...          ...       ...
# 9574               Uniswap V2: BAC-DAI     359.808313      $0.5997  BAC(BAC)
# 9575                                       359.808313      $0.5997  BAC(BAC)
# 9576               Uniswap V2: BAC-DAI            100      $0.1667  BAC(BAC)
# 9577                                              100      $0.1667  BAC(BAC)
# 9578               Uniswap V2: BAC-DAI   1,546.999532        $2.58  BAC(BAC)
#
#        Txn Fee
# 0     0.017547
# 1     0.017547
# 2     0.008582
# 3     0.004365
# 4     0.004985
# ...        ...
# 9574  0.006827
# 9575  0.011219
# 9576  0.013267
# 9577  0.009761
# 9578  0.008138
#
# [9579 rows x 14 columns]

# %%
df['Block'].nunique()
df['Amount'] = df['Amount'].str.replace(',', '')
df['Amount'] = pd.to_numeric(df['Amount'])
df['day'] = df['Date Time (UTC)'].str[8:10].astype(int)
df['month'] = df['Date Time (UTC)'].str[5:7].astype(int)

# %%
df = df.sort_values(by=['day'])
df
# Out:
#                                        Transaction Hash   Status    Type  \
# 3211  0x1105122b327d1c1ecdde1bafc7aae6507671405c38a6...  Success  ERC-20
# 3193  0x3c0c1e1b4c7dbafd13efa539c8c5a15c7ee9fa24b511...  Success  ERC-20
# 3192  0xb59346961bbe95dd32ad8a4174fff3f1aa44d676aef3...  Success  ERC-20
# 3191  0xabe2b9345efb582d32c6a686121e90b1b1400cc2c235...  Success  ERC-20
# 3190  0xc572da3b6dc84df4b7e5a1738036b80cf254b7337f2f...  Success  ERC-20
# ...                                                 ...      ...     ...
# 720   0x27f1b6fa46eed27fc12f05b11aebdc39b60234523c93...  Success  ERC-20
# 719   0x26302b8aa3135d78f2712d959b7ae3fe0843c065de50...  Success  ERC-20
# 718   0x96e38eab0f1cb9e0293761ac5bb238e0a5bdb7b052ff...  Success  ERC-20
# 716   0xc4a08038c3f0027c0abfe367f658b5ac2d64934235e8...  Success  ERC-20
# 6077  0x60262fa72fad608c1ba38554244b3ef8752e8a8fa16b...  Success  ERC-20
#
#                            Method      Block      Date Time (UTC)  \
# 3211     Swap Exact ETH For Tokens  11614396  2021-01-08 13:37:55
# 3193  Swap Exact Tokens For Tokens  11614480  2021-01-08 13:57:00
# 3192                 Add Liquidity  11614482  2021-01-08 13:57:35
# 3191  Swap Exact Tokens For Tokens  11614483  2021-01-08 13:57:43
# 3190  Swap Exact Tokens For Tokens  11614483  2021-01-08 13:57:43
# ...                            ...       ...                  ...
# 720   Swap Exact Tokens For Tokens  11676353   2021-01-18 1:48:24
# 719                     0x3a57af38  11676362   2021-01-18 1:50:10
# 718   Swap Tokens For Exact Tokens  11676381   2021-01-18 1:53:31
# 716   Swap Exact Tokens For Tokens  11676387   2021-01-18 1:55:03
# 6077     Swap ETH For Exact Tokens  11680687  2021-01-18 17:47:02
#
#                                             From          From_NameTag  \
# 3211  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 3193  0xd4f8a1bbee54c1533cf0ef8c6f877ada4dadca1b             jinwd.eth
# 3192  0x6bf0443aE7288a126C7a798572ad43Ae78C62b6F
# 3191  0xE388bE45Ea5Acf7443592948F59f3dA9eE840E52
# 3190  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# ...                                          ...                   ...
# 720   0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 719   0xe088fb588d2c06b4cedce88d97c18e577e0e3dea  Uniswap V2: BAC-Mars
# 718   0x06c05D0214Ab6d293D4Ece9b7fcE7c5cF3856892
# 716   0x09be9ab0eb61327d26904bae69efdc6633d5eec8       milkbutcher.eth
# 6077  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
#
#                                               To            To_NameTag  \
# 3211  0x44Acd0Ff3bE9Fdfb932453C82B5dF5739D28b276
# 3193  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 3192  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 3191  0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 3190  0x2F92Dd1c3c25Dd02eBA81b9aC1D3C46400f2230F
# ...                                          ...                   ...
# 720   0x4560ebb130f87ce8a3c0cb7285def7a520bfc018             wweb3.eth
# 719   0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 718   0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 716   0xd4405f0704621dbe9d4dea60e128e0c3b26bddbd   Uniswap V2: BAC-DAI
# 6077  0x0530F6B3f76b30cC4FFE829C08eaEBC8dE767290
#
#             Amount Value (USD)      Asset   Txn Fee  day  month
# 3211   6436.656395       $10.73  BAC(BAC)  0.035034    8      1
# 3193   4498.539827        $7.50  BAC(BAC)  0.025883    8      1
# 3192  23944.493878       $39.92  BAC(BAC)  0.023575    8      1
# 3191  36059.585245       $60.12  BAC(BAC)  0.012166    8      1
# 3190   5204.015341        $8.68  BAC(BAC)  0.017315    8      1
# ...            ...          ...       ...       ...  ...    ...
# 720    2141.909121        $3.57  BAC(BAC)  0.005479   18      1
# 719    2817.699923        $4.70  BAC(BAC)  0.021566   18      1
# 718    7557.670173       $12.60  BAC(BAC)  0.018620   18      1
# 716   30000.000000       $50.00  BAC(BAC)  0.004986   18      1
# 6077      3.000000  $0.00500043  BAC(BAC)  0.016789   18      1
#
# [9579 rows x 16 columns]

# %%
transactions = df[['day', 'Amount']].sort_values(by = ['day'])
transactions
# Out:
#       day        Amount
# 3211    8   6436.656395
# 9177    8     91.324145
# 9176    8  50979.533128
# 9175    8   1543.077343
# 9174    8    625.084827
# ...   ...           ...
# 6036   18  55483.715337
# 6037   18    574.871451
# 6038   18  55485.095694
# 6055   18  66326.708405
# 6077   18      3.000000
#
# [9579 rows x 2 columns]

# %%
prices = pd.read_csv('bac-usd-max.csv')
prices['month'] = prices['snapped_at'].str[5:7].astype(int)
prices['day'] = prices['snapped_at'].str[8:10].astype(int)
prices['year'] = prices['snapped_at'].str[0:4].astype(int)
prices = prices[prices['month'] == 1]
prices = prices[prices['year'] == 2021]
prices = prices[(prices['day'] >= 8) & (prices['day'] <= 18)]
prices = prices[['day', 'price']]
prices
# Out:
#     day     price
# 39    8  0.995630
# 40    9  0.875197
# 41   10  0.880279
# 42   11  0.870669
# 43   12  0.724765
# 44   13  0.755624
# 45   14  0.838819
# 46   15  0.900027
# 47   16  0.843679
# 48   17  0.746980
# 49   18  0.666624

# %%
#Jan 8, 2021 to Jan 18, 2021 supplies for basis cash
supplies_basis = [
85120197.197678980428723026,
64432188.689977877935469257,
61899676.386977877935469257,
61789381.007977877935469257,
61419302.745977877935469257,
61326688.712977877935469257,
61314996.033977877935469257,
61312100.084977877935469257,
61312100.084977877935469257,
61312100.084977877935469257,
61312100.084977877935469257,
]
supplies_basis
# Out:
# [85120197.19767898,
#  64432188.68997788,
#  61899676.38697788,
#  61789381.00797788,
#  61419302.74597788,
#  61326688.71297788,
#  61314996.03397788,
#  61312100.08497788,
#  61312100.08497788,
#  61312100.08497788,
#  61312100.08497788]

# %%
# Basis bond supplies from jan 8 to jan 18 2021
bond_supplies_basis = [
4864677.002696151625832751,
34759967.369810053015255691,
37665775.575794274333252528,
37807986.32750924880049198,
38320544.053049135506206476,
38432272.247365204750774165,
38446182.422907559743523843,
38449434.403917323852613117,
38449434.403917323852613117,
38449434.403917323852613117,
38449434.403917323852613117
]

# %%
#Jan 6, 2021 to Jan 30, 2021 supplies for new stablecoin cash
supplies = [
85123969.067612940197407694,
84892669.857427112322538373,
67249698.377024272285284295,
64639796.106518674822138937,
62464723.999693715070888088,
58218865.330298229771453565,
55228686.730918503165567044,
41608147.804783343137842546,
37615783.589624921063157343,
34953031.042611951004780352,
31810009.055968734473196859,
]
supplies
# Out:
# [85123969.06761295,
#  84892669.8574271,
#  67249698.37702428,
#  64639796.10651868,
#  62464723.999693714,
#  58218865.33029823,
#  55228686.730918504,
#  41608147.804783344,
#  37615783.58962492,
#  34953031.04261195,
#  31810009.055968735]

# %%
bond_supplies = [
28.253542261566621751,
232365.984513336505536682,
20391214.317338733608525916,
23356167.217939447322657512,
25855146.199808308202880457,
31699292.882006190660460437,
35656056.599785470567110721,
51893815.019617881061241684,
56329700.491390926508769214,
59487311.405247736828305750,
63694968.007319395621959804
]

# %%
merged_df = transactions.merge(prices, on='day', how='inner')
merged_df.to_csv('transactions.csv')
merged_df
# Out:
#       day        Amount     price
# 0       8   6436.656395  0.995630
# 1       8     91.324145  0.995630
# 2       8  50979.533128  0.995630
# 3       8   1543.077343  0.995630
# 4       8    625.084827  0.995630
# ...   ...           ...       ...
# 9574   18  55483.715337  0.666624
# 9575   18    574.871451  0.666624
# 9576   18  55485.095694  0.666624
# 9577   18  66326.708405  0.666624
# 9578   18      3.000000  0.666624
#
# [9579 rows x 3 columns]

# %%
sum(merged_df['Amount'])
# Out:
# 456064065.4419672

# %%
days = [i for i in range(8 - 8, 19 - 8)]
plt.plot(days, supplies_basis, label='Basis Cash')
plt.plot(days, supplies, label='Improved')
plt.title('Supply Over Time')
plt.xlabel('Time (day)')
plt.ylabel('Supply')
plt.legend()
plt.show()
# Out:
# Shows cash supply from Jan 8, 2021 to Jan 18, 2021 (when Basis Cash depeg occurred and never recovered)

# %%
days = [i for i in range(8 - 8, 19 - 8)]
plt.plot(days, bond_supplies_basis, label='Basis Cash')
plt.plot(days, bond_supplies, label='Improved')
plt.title('Supply Over Time')
plt.xlabel('Time (day)')
plt.ylabel('Supply')
plt.legend()
plt.show()
